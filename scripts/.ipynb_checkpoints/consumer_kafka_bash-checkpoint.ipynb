# %%
from kafka import KafkaConsumer
import json

# Configuración del consumidor

print('Iniciando consumidor...')

consumer = KafkaConsumer(
    'kfk_stream_transactions', 
    bootstrap_servers='broker-kafka:29092',
    group_id='my-consumer-group',  # Grupo de consumidores
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

print('Iniciando consumidor...')

for message in consumer:
    print("Mensaje recibido:", message.value)
# Out:
# Iniciando consumidor...
# Iniciando consumidor...
# Recibido: 3
# Recibido: 1
# Recibido: 2
# Recibido: 3
# Recibido: 8
# Recibido: 6
# Recibido: 7
# Recibido: 9
# Recibido: 7
# Recibido: 8
# Recibido: 9
# Recibido: 2
# Recibido: 4
# Recibido: 1
# Recibido: 5
# Recibido: 5
# Recibido: 4
# Recibido: 7
# Recibido: 3
# Recibido: 5
# Recibido: 9
# Recibido: 7
# Recibido: 2
# Recibido: 5
# Recibido: 4
# Recibido: 3
# Recibido: 7
# Recibido: 3
# Recibido: 3
# Recibido: 8
# Recibido: 9
# Recibido: 5
# Recibido: 7
# Recibido: 3
# Recibido: 6
# Recibido: 6
# Recibido: 7
# Recibido: 1
# Recibido: 1
# Recibido: 3
# Recibido: 6
# Recibido: 2
# Recibido: 2
# Recibido: 8
# Recibido: 8
# Recibido: 6
# Recibido: 1
# Recibido: 7
# Recibido: 5
# Recibido: 5
# Recibido: 4
# Recibido: 3
# Recibido: 2
# Recibido: 9
# Recibido: 1
# Recibido: 4
# Recibido: 9
# Recibido: 4
# Recibido: 8
# Recibido: 7
# Recibido: 7
# Recibido: 9
# Recibido: 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 18
#      15 print('Iniciando consumidor...')
#      17 for message in consumer:
# ---> 18     print(f'Recibido: {message.value["valor"]}')
#
# KeyError: 'valor'

# %%
from kafka import KafkaConsumer
import json

# Configuración del consumidor

print('Iniciando consumidor...')

consumer = KafkaConsumer(
    'kfk_stream_transactions', 
    bootstrap_servers='broker-kafka:29092',
    group_id='my-consumer-group',  # Grupo de consumidores
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

print('Iniciando consumidor...')

for message in consumer:
    print(f'Recibido: {message.value["valor"]}')
