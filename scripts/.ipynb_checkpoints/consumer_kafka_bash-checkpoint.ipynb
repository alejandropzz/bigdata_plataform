# %%
from kafka import KafkaConsumer
import json

# Crear el consumidor
consumer = KafkaConsumer(
    'mysql.binlog.events',
    bootstrap_servers='broker-kafka:29092',
    auto_offset_reset='earliest',  # Para leer desde el principio
    enable_auto_commit=True,
    group_id='grupo-mysql-consumer',
    value_deserializer=lambda m: json.loads(m.decode('utf-8'))
)

print('Esperando mensajes del topic mysql.binlog.events...')

# Leer mensajes
for mensaje in consumer:
    print(f"Mensaje recibido:\n{json.dumps(mensaje.value, indent=2)}\n")
# Out:
# Esperando mensajes del topic mysql.binlog.events...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[2], line 17
#      14 print('Esperando mensajes del topic mysql.binlog.events...')
#      16 # Leer mensajes
# ---> 17 for mensaje in consumer:
#      18     print(f"Mensaje recibido:\n{json.dumps(mensaje.value, indent=2)}\n")
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:735, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     732 if self._coordinator.need_rejoin():
#     733     return {}
# --> 735 records, _ = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     736 return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:346, in Fetcher.fetched_records(self, max_records, update_offsets)
#     344 except Exception as e:
#     345     if not drained:
# --> 346         raise e
#     347     # To be thrown in the next call of this method
#     348     self._next_in_line_exception_metadata = ExceptionMetadata(fetched_partition, fetched_offset, e)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:340, in Fetcher.fetched_records(self, max_records, update_offsets)
#     338             fetched_partition = self._next_partition_records.topic_partition
#     339             fetched_offset = self._next_partition_records.next_fetch_offset
# --> 340             records_remaining -= self._append(drained,
#     341                                               self._next_partition_records,
#     342                                               records_remaining,
#     343                                               update_offsets)
#     344 except Exception as e:
#     345     if not drained:
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:374, in Fetcher._append(self, drained, part, max_records, update_offsets)
#     371 if part.next_fetch_offset == position.offset:
#     372     log.debug("Returning fetched records at offset %d for assigned"
#     373               " partition %s", position.offset, tp)
# --> 374     part_records = part.take(max_records)
#     375     # list.extend([]) is a noop, but because drained is a defaultdict
#     376     # we should avoid initializing the default list unless there are records
#     377     if part_records:
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:970, in Fetcher.PartitionRecords.take(self, n)
#     968 except Exception as e:
#     969     if not records:
# --> 970         raise e
#     971     # To be thrown in the next call of this method
#     972     self._next_inline_exception = e
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:967, in Fetcher.PartitionRecords.take(self, n)
#     964 records = []
#     965 try:
#     966     # Note that records.extend(iter) will extend partially when exception raised mid-stream
# --> 967     records.extend(itertools.islice(self.record_iterator, 0, n))
#     968 except Exception as e:
#     969     if not records:
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:1027, in Fetcher.PartitionRecords._unpack_records(self, tp, records, key_deserializer, value_deserializer)
#    1025 value_size = len(record.value) if record.value is not None else -1
#    1026 key = self._deserialize(key_deserializer, tp.topic, record.key)
# -> 1027 value = self._deserialize(value_deserializer, tp.topic, record.value)
#    1028 headers = record.headers
#    1029 header_size = sum(
#    1030     len(h_key.encode("utf-8")) + (len(h_val) if h_val is not None else 0) for h_key, h_val in
#    1031     headers) if headers else -1
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/fetcher.py:1063, in Fetcher.PartitionRecords._deserialize(self, f, topic, bytes_)
#    1061 if isinstance(f, Deserializer):
#    1062     return f.deserialize(topic, bytes_)
# -> 1063 return f(bytes_)
#
# Cell In[2], line 11, in <lambda>(m)
#       2 import json
#       4 # Crear el consumidor
#       5 consumer = KafkaConsumer(
#       6     'mysql.binlog.events',
#       7     bootstrap_servers='broker-kafka:29092',
#       8     auto_offset_reset='earliest',  # Para leer desde el principio
#       9     enable_auto_commit=True,
#      10     group_id='grupo-mysql-consumer',
# ---> 11     value_deserializer=lambda m: json.loads(m.decode('utf-8'))
#      12 )
#      14 print('Esperando mensajes del topic mysql.binlog.events...')
#      16 # Leer mensajes
#
# File /opt/conda/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/conda/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/conda/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 85 (char 84)

# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer(
    'mysql.binlog.events',
    bootstrap_servers='broker-kafka:29092',
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='grupo-mysql-consumer',
    value_deserializer=lambda m: m  # No decodificamos
)

print('Esperando mensajes del topic mysql.binlog.events...')

for mensaje in consumer:
    print(f"Raw message bytes:\n{mensaje.value}\n")
# Out:
# Esperando mensajes del topic mysql.binlog.events...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#       3 consumer = KafkaConsumer(
#       4     'mysql.binlog.events',
#       5     bootstrap_servers='broker-kafka:29092',
#    (...)
#       9     value_deserializer=lambda m: m  # No decodificamos
#      10 )
#      12 print('Esperando mensajes del topic mysql.binlog.events...')
# ---> 14 for mensaje in consumer:
#      15     print(f"Raw message bytes:\n{mensaje.value}\n")
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1188, in KafkaConsumer.__next__(self)
#    1186     self._iterator = self._message_generator_v2()
#    1187 try:
# -> 1188     return next(self._iterator)
#    1189 except StopIteration:
#    1190     self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1160, in KafkaConsumer._message_generator_v2(self)
#    1158 def _message_generator_v2(self):
#    1159     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1160     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1161     for tp, records in six.iteritems(record_map):
#    1162         # Generators are stateful, and it is possible that the tp / records
#    1163         # here may become stale during iteration -- i.e., we seek to a
#    1164         # different offset, pause consumption, or lose assignment.
#    1165         for record in records:
#    1166             # is_fetchable(tp) should handle assignment changes and offset
#    1167             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1168             # outer function destroying the existing iterator/generator
#    1169             # via self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 timer = Timer(timeout_ms)
#     683 while not self._closed:
# --> 684     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:701, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     691 def _poll_once(self, timer, max_records, update_offsets=True):
#     692     """Do one round of polling. In addition to checking for new data, this does
#     693     any needed heart-beating, auto-commits, and offset updates.
#     694
#    (...)
#     699         dict: Map of topic to list of records (may be empty).
#     700     """
# --> 701     if not self._coordinator.poll(timeout_ms=timer.timeout_ms):
#     702         return {}
#     704     has_all_fetch_positions = self._update_fetch_positions(timeout_ms=timer.timeout_ms)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/coordinator/consumer.py:298, in ConsumerCoordinator.poll(self, timeout_ms)
#     295         if not metadata_update.is_done:
#     296             return False
# --> 298     if not self.ensure_active_group(timeout_ms=timer.timeout_ms):
#     299         return False
#     301 self.poll_heartbeat()
#
# File /opt/conda/lib/python3.11/site-packages/kafka/coordinator/base.py:429, in BaseCoordinator.ensure_active_group(self, timeout_ms)
#     427     return False
#     428 self._start_heartbeat_thread()
# --> 429 return self.join_group(timeout_ms=timer.timeout_ms)
#
# File /opt/conda/lib/python3.11/site-packages/kafka/coordinator/base.py:474, in BaseCoordinator.join_group(self, timeout_ms)
#     471     continue
#     473 future = self._initiate_join_group()
# --> 474 self._client.poll(future=future, timeout_ms=timer.timeout_ms)
#     475 if future.is_done:
#     476     self._reset_join_group_future()
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /opt/conda/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
from kafka import KafkaConsumer

consumer = KafkaConsumer(
    'mysql.binlog.events',
    bootstrap_servers='broker-kafka:29092',
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    group_id='grupo-mysql-consumer',
    value_deserializer=lambda m: m  # No decodificar
)

print('Esperando mensajes del topic mysql.binlog.events...')

for mensaje in consumer:
    raw_bytes = mensaje.value
    print("PZZ")
    try:
        raw_str = raw_bytes.decode('utf-8')
    except Exception as e:
        raw_str = f"<Error decodificando utf-8: {e}>"
    print(f"Mensaje bytes: {raw_bytes}")
    print(f"Mensaje utf-8: {raw_str}\n{'='*40}")
# Out:
# Esperando mensajes del topic mysql.binlog.events...
